# %% [markdown]
# # KymFlow Quick Start
#
# This is a minimal starter notebook bundled with the constructor scaffold.

# %%
import kymflow
print('kymflow import OK')
from importlib.metadata import version
print(version("kymflow"))
# Out:
# kymflow import OK
# 0.2.3

# %%
from kymflow.core.image_loaders.kym_image_list import KymImageList

path = '/Users/cudmore/Downloads/kymflow_app/declan_20260313/small-data'

kil = KymImageList(path=path)

print(kil)
# Out:
# AcqImageList(mode: folder, source: /Users/cudmore/Downloads/kymflow_app/declan_20260313/small-data, depth: 4, file_extension: .tif, ignore_file_stub: None, images: 128)

# %%
for ki in kil:
    print(ki)
# Out:
# KymImage paths=ch1:20250507_A79_0002.tif, shape=(30000, 12)
# KymImage paths=ch1:20250507_A79_0003.tif, shape=(30000, 13)
# KymImage paths=ch1:20250507_A79_0004.tif, shape=(30000, 12)
# KymImage paths=ch1:20250507_A79_0005.tif, shape=(30000, 15)
# KymImage paths=ch1:20250507_A79_0006.tif, shape=(30000, 16)
# KymImage paths=ch1:20250507_A79_0007.tif, shape=(30000, 12)
# KymImage paths=ch1:20250507_A79_0008.tif, shape=(30000, 9)
# KymImage paths=ch1:20250507_A79_0009.tif, shape=(30000, 12)
# KymImage paths=ch1:20250507_A79_0010.tif, shape=(30000, 9)
# KymImage paths=ch1:20250507_A79_0011.tif, shape=(30000, 20)
# KymImage paths=ch1:20250507_A79_0012.tif, shape=(30000, 13)
# KymImage paths=ch1:20250507_A79_0013.tif, shape=(30000, 14)
# KymImage paths=ch1:20250507_A79_0014.tif, shape=(30000, 21)
# KymImage paths=ch1:20251105_A109_0002.tif, shape=(30000, 19)
# KymImage paths=ch1:20251105_A109_0003.tif, shape=(30000, 22)
# KymImage paths=ch1:20251105_A109_0004.tif, shape=(30000, 16)
# ...
